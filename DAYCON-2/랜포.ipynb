# %%
import pandas as pd
import numpy as np
import optuna
import os
# 환경 변수로 인코딩 문제 해결
os.environ['JOBLIB_TEMP_FOLDER'] = 'C:/temp'  # 영문 경로 사용
os.makedirs('C:/temp', exist_ok=True)
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.ensemble import RandomForestRegressor
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski, MACCSkeys, AllChem
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb

# %%
print("데이터 로딩 중...")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
submission = pd.read_csv("sample_submission.csv")

print(f"훈련 데이터 : {train.shape}")
print(f"테스트 데이터 : {test.shape}")
# Out:
# 데이터 로딩 중...
# 훈련 데이터 : (1681, 3)
# 테스트 데이터 : (100, 2)

# %%
def get_molecule_descriptors(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return [0] * 2232

        basic_descriptors = [
            Descriptors.MolWt(mol),
            Descriptors.MolLogP(mol),
            Descriptors.NumHAcceptors(mol),
            Descriptors.NumHDonors(mol),
            Descriptors.TPSA(mol),
            Descriptors.NumRotatableBonds(mol),
            Descriptors.NumAromaticRings(mol),
            Descriptors.NumHeteroatoms(mol),
            Descriptors.FractionCSP3(mol),
            Descriptors.NumAliphaticRings(mol),
            Lipinski.NumAromaticHeterocycles(mol),
            Lipinski.NumSaturatedHeterocycles(mol),
            Lipinski.NumAliphaticHeterocycles(mol),
            Descriptors.HeavyAtomCount(mol),
            Descriptors.RingCount(mol),
            Descriptors.NOCount(mol),
            Descriptors.NHOHCount(mol),
            Descriptors.NumRadicalElectrons(mol),
        ]

        morgan_fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        morgan_features = [int(bit) for bit in morgan_fp.ToBitString()]

        maccs_fp = MACCSkeys.GenMACCSKeys(mol)
        maccs_features = [int(bit) for bit in maccs_fp.ToBitString()]

        all_features = basic_descriptors + morgan_features + maccs_features

        return all_features
    except:
        return [0] * 2232

print("분자 특성 추출 중...")
# Out:
# 분자 특성 추출 중...

# %%
# 1. 훈련 데이터 특성 추출
train['features'] = train['Canonical_Smiles'].apply(get_molecule_descriptors)

# 2. 훈련 데이터 길이 통일
X_train_list = train['features'].tolist()
feature_lengths = [len(x) for x in X_train_list]

if len(set(feature_lengths)) != 1:
    max_length = max(feature_lengths)
    X_train_list = [x + [0] * (max_length - len(x)) for x in X_train_list]

# 3. NumPy 배열로 변환
X_train = np.array(X_train_list)
y_train = train['Inhibition'].values

# 4. 테스트 데이터 특성 추출
test['features'] = test['Canonical_Smiles'].apply(get_molecule_descriptors)
X_test_list = test['features'].tolist()
feature_lengths = [len(x) for x in X_test_list]

if len(set(feature_lengths)) != 1:
    max_length = max(feature_lengths)
    X_test_list = [x + [0] * (max_length - len(x)) for x in X_test_list]

# 5. 훈련/테스트 데이터 간 차원 정합
if X_train.shape[1] != len(X_test_list[0]):
    diff = abs(X_train.shape[1] - len(X_test_list[0]))
    if X_train.shape[1] > len(X_test_list[0]):
        X_test_list = [x + [0] * diff for x in X_test_list]
    else:
        X_train = np.array([x.tolist() + [0] * diff for x in X_train])

# 6. 최종 테스트 데이터 배열 변환
X_test = np.array(X_test_list)

print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"특성 벡터 구성: 기본 특성(18) + Morgan(2048) + MACCS(166) = 총 {X_train.shape[1]}개")
# Out:
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:31] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:32] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# [13:36:33] DEPRECATION WARNING: please use MorganGenerator
# ...
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:35] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# X_train: (1681, 2233), X_test: (100, 2233)
# 특성 벡터 구성: 기본 특성(18) + Morgan(2048) + MACCS(166) = 총 2233개
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator
# [13:36:36] DEPRECATION WARNING: please use MorganGenerator

# %%
# 데이터 스케일링 (Random Forest는 스케일링이 필수는 아니지만 성능 향상 가능)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 검증을 위한 데이터 분할
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_scaled, y_train, test_size=0.2, random_state=42
)

# 평가 함수들
def normalized_rmse(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    return rmse / (np.max(y_true) - np.min(y_true))

def pearson_correlation(y_true, y_pred):
    corr = np.corrcoef(y_true, y_pred)[0, 1]
    return np.clip(corr, 0, 1)

def competition_score(y_true, y_pred):
    nrmse = min(normalized_rmse(y_true, y_pred), 1)
    pearson = pearson_correlation(y_true, y_pred)
    return 0.5 * (1 - nrmse) + 0.5 * pearson

# make_scorer: 사용자 정의 함수를 scikit-learn 호환 스코어러로 변환
competition_scorer = make_scorer(competition_score, greater_is_better=True)

# %%
def objective(trial):
    # 논문 기반 하이퍼파라미터 범위 설정
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 2000),  # 논문: 100-2000
        'max_depth': trial.suggest_int('max_depth', 5, 50),  # 논문: 5-50, None도 포함
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),  # 논문: 2-20
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),  # 논문: 1-10
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', 0.1, 0.3, 0.5]),  # 논문: 다양한 선택
        'bootstrap': True,  # 고정값
        'oob_score': True,  # OOB 점수 계산
        'random_state': 42,  # 재현성
        'n_jobs': -1  # 병렬 처리
    }
    
    # max_depth가 너무 클 경우 None으로 설정
    if params['max_depth'] > 40:
        params['max_depth'] = None
    
    # Random Forest 모델 생성
    model = RandomForestRegressor(**params)
    
    # 3-fold CV로 Competition Score 평가 (빠른 평가를 위해)
    cv_scores = cross_val_score(
        model, X_train_scaled, y_train, 
        cv=3, scoring=competition_scorer, n_jobs=-1
    )
    
    return cv_scores.mean()

# %%
# Optuna 스터디 생성
print("Optuna 하이퍼파라미터 최적화 시작...")
study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=42),
    pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
)

# 최적화 실행 (논문 기준: 100-200회 시도)
n_trials = 100
study.optimize(objective, n_trials=n_trials, timeout=3600)  # 1시간 제한

print("최적화 완료!")
print(f"최고 점수: {study.best_value:.4f}")
print(f"최적 하이퍼파라미터:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# [I 2025-07-06 13:36:36,603] A new study created in memory with name: no-name-2eccf4ad-32ed-4efb-9428-ad83b0f5c231
# Optuna 하이퍼파라미터 최적화 시작...
# [I 2025-07-06 13:36:47,528] Trial 0 finished with value: 0.5921311325416251 and parameters: {'n_estimators': 812, 'max_depth': 48, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.3}. Best is trial 0 with value: 0.5921311325416251.
# [I 2025-07-06 13:37:02,767] Trial 1 finished with value: 0.5866816705491664 and parameters: {'n_estimators': 1446, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 0 with value: 0.5921311325416251.
# [I 2025-07-06 13:37:16,476] Trial 2 finished with value: 0.5931111859500033 and parameters: {'n_estimators': 921, 'max_depth': 18, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 0.3}. Best is trial 2 with value: 0.5931111859500033.
# [I 2025-07-06 13:37:29,260] Trial 3 finished with value: 0.593227072891214 and parameters: {'n_estimators': 1077, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 0.3}. Best is trial 3 with value: 0.593227072891214.
# [I 2025-07-06 13:37:38,199] Trial 4 finished with value: 0.5942448911296262 and parameters: {'n_estimators': 679, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 0.3}. Best is trial 4 with value: 0.5942448911296262.
# [I 2025-07-06 13:37:45,040] Trial 5 finished with value: 0.5688907505262849 and parameters: {'n_estimators': 1359, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 4 with value: 0.5942448911296262.
# [I 2025-07-06 13:38:08,545] Trial 6 finished with value: 0.5925960420970059 and parameters: {'n_estimators': 1236, 'max_depth': 47, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 4 with value: 0.5942448911296262.
# [I 2025-07-06 13:38:13,384] Trial 7 finished with value: 0.5956573304771431 and parameters: {'n_estimators': 778, 'max_depth': 17, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 7 with value: 0.5956573304771431.
# [I 2025-07-06 13:38:14,857] Trial 8 finished with value: 0.5854805267859947 and parameters: {'n_estimators': 110, 'max_depth': 42, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 7 with value: 0.5956573304771431.
# [I 2025-07-06 13:38:27,578] Trial 9 finished with value: 0.5950457665743997 and parameters: {'n_estimators': 1284, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 0.3}. Best is trial 7 with value: 0.5956573304771431.
# [I 2025-07-06 13:38:41,393] Trial 10 finished with value: 0.5969334980915998 and parameters: {'n_estimators': 1896, 'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:38:54,519] Trial 11 finished with value: 0.5954108329625337 and parameters: {'n_estimators': 1825, 'max_depth': 33, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:06,510] Trial 12 finished with value: 0.5968094217074905 and parameters: {'n_estimators': 1986, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:17,937] Trial 13 finished with value: 0.5959147454941448 and parameters: {'n_estimators': 1943, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:25,540] Trial 14 finished with value: 0.59625944400528 and parameters: {'n_estimators': 1671, 'max_depth': 38, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:35,392] Trial 15 finished with value: 0.5953086293866237 and parameters: {'n_estimators': 1585, 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:47,500] Trial 16 finished with value: 0.5959859477265449 and parameters: {'n_estimators': 1999, 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:54,737] Trial 17 finished with value: 0.5806150791093304 and parameters: {'n_estimators': 1775, 'max_depth': 38, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:39:56,651] Trial 18 finished with value: 0.5738065378798535 and parameters: {'n_estimators': 465, 'max_depth': 31, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:40:06,563] Trial 19 finished with value: 0.5958754195360162 and parameters: {'n_estimators': 1541, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:40:16,934] Trial 20 finished with value: 0.5958607076374064 and parameters: {'n_estimators': 1804, 'max_depth': 36, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 10 with value: 0.5969334980915998.
# [I 2025-07-06 13:40:24,790] Trial 21 finished with value: 0.5969992102648051 and parameters: {'n_estimators': 1673, 'max_depth': 42, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:40:34,130] Trial 22 finished with value: 0.5956404413129232 and parameters: {'n_estimators': 1993, 'max_depth': 43, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:40:41,573] Trial 23 finished with value: 0.5958415202480639 and parameters: {'n_estimators': 1703, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:40:49,842] Trial 24 finished with value: 0.5933563131660865 and parameters: {'n_estimators': 1875, 'max_depth': 43, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:01,498] Trial 25 finished with value: 0.5959599010923321 and parameters: {'n_estimators': 1511, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:08,078] Trial 26 finished with value: 0.5813137727612884 and parameters: {'n_estimators': 1645, 'max_depth': 36, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:13,030] Trial 27 finished with value: 0.59008491785805 and parameters: {'n_estimators': 1174, 'max_depth': 50, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:22,407] Trial 28 finished with value: 0.5967459443341481 and parameters: {'n_estimators': 1435, 'max_depth': 41, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:33,503] Trial 29 finished with value: 0.5958803531159186 and parameters: {'n_estimators': 1851, 'max_depth': 46, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:41,499] Trial 30 finished with value: 0.594559093695069 and parameters: {'n_estimators': 1730, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:41:50,960] Trial 31 finished with value: 0.5967813703842598 and parameters: {'n_estimators': 1400, 'max_depth': 41, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:42:00,534] Trial 32 finished with value: 0.5955215989718915 and parameters: {'n_estimators': 1449, 'max_depth': 34, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:42:10,875] Trial 33 finished with value: 0.5957172039558449 and parameters: {'n_estimators': 1598, 'max_depth': 40, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:42:47,701] Trial 34 finished with value: 0.5919571897456772 and parameters: {'n_estimators': 1909, 'max_depth': 45, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.5}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:42:54,024] Trial 35 finished with value: 0.5955717947003668 and parameters: {'n_estimators': 995, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:43:06,425] Trial 36 finished with value: 0.5923329845050228 and parameters: {'n_estimators': 1365, 'max_depth': 35, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.3}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:43:13,083] Trial 37 finished with value: 0.5657494901179695 and parameters: {'n_estimators': 1737, 'max_depth': 39, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:43:33,151] Trial 38 finished with value: 0.5924291948282318 and parameters: {'n_estimators': 1188, 'max_depth': 49, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 21 with value: 0.5969992102648051.
# [I 2025-07-06 13:43:47,761] Trial 39 finished with value: 0.5980671632923581 and parameters: {'n_estimators': 1892, 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:44:11,425] Trial 40 finished with value: 0.5934276884111492 and parameters: {'n_estimators': 1893, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.3}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:44:24,370] Trial 41 finished with value: 0.5972530073725387 and parameters: {'n_estimators': 1785, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:44:37,254] Trial 42 finished with value: 0.5954549206357174 and parameters: {'n_estimators': 1805, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:44:54,135] Trial 43 finished with value: 0.5961507100684132 and parameters: {'n_estimators': 1944, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:45:05,659] Trial 44 finished with value: 0.5962486206389807 and parameters: {'n_estimators': 1658, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:45:10,080] Trial 45 finished with value: 0.5954122696220917 and parameters: {'n_estimators': 583, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:45:40,781] Trial 46 finished with value: 0.5924946981795112 and parameters: {'n_estimators': 1868, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.5}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:45:56,382] Trial 47 finished with value: 0.5967022106323348 and parameters: {'n_estimators': 1991, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:03,265] Trial 48 finished with value: 0.5799517102351653 and parameters: {'n_estimators': 1769, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:12,059] Trial 49 finished with value: 0.5947288589714382 and parameters: {'n_estimators': 1542, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:13,449] Trial 50 finished with value: 0.5912189416413226 and parameters: {'n_estimators': 144, 'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 0.3}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:24,086] Trial 51 finished with value: 0.5976643690899363 and parameters: {'n_estimators': 1628, 'max_depth': 37, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:36,064] Trial 52 finished with value: 0.5961445763243517 and parameters: {'n_estimators': 1646, 'max_depth': 37, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:46:47,954] Trial 53 finished with value: 0.5967688003315023 and parameters: {'n_estimators': 1809, 'max_depth': 34, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:02,559] Trial 54 finished with value: 0.5973484585762459 and parameters: {'n_estimators': 1919, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:09,546] Trial 55 finished with value: 0.5854002998341895 and parameters: {'n_estimators': 1710, 'max_depth': 38, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:24,443] Trial 56 finished with value: 0.5968387413739116 and parameters: {'n_estimators': 1924, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:34,581] Trial 57 finished with value: 0.5956842881798431 and parameters: {'n_estimators': 1308, 'max_depth': 35, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:41,387] Trial 58 finished with value: 0.5912614928294418 and parameters: {'n_estimators': 1591, 'max_depth': 44, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:47,090] Trial 59 finished with value: 0.5961919771260369 and parameters: {'n_estimators': 819, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:47:58,230] Trial 60 finished with value: 0.5963316267294577 and parameters: {'n_estimators': 1481, 'max_depth': 37, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:48:13,266] Trial 61 finished with value: 0.5963683776773417 and parameters: {'n_estimators': 1919, 'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:48:26,193] Trial 62 finished with value: 0.5969383991914164 and parameters: {'n_estimators': 1832, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:48:38,890] Trial 63 finished with value: 0.5968674847840859 and parameters: {'n_estimators': 1772, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:48:51,836] Trial 64 finished with value: 0.5970849626523044 and parameters: {'n_estimators': 1830, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:49:03,286] Trial 65 finished with value: 0.5951518411742721 and parameters: {'n_estimators': 1835, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:49:10,944] Trial 66 finished with value: 0.5952434215473371 and parameters: {'n_estimators': 1685, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:49:22,588] Trial 67 finished with value: 0.595278064859382 and parameters: {'n_estimators': 1857, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:49:29,557] Trial 68 finished with value: 0.5824604734328135 and parameters: {'n_estimators': 1746, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:50:00,539] Trial 69 finished with value: 0.5923029363624438 and parameters: {'n_estimators': 1623, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:50:12,072] Trial 70 finished with value: 0.5959538284472062 and parameters: {'n_estimators': 1963, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:50:26,969] Trial 71 finished with value: 0.5979924282658353 and parameters: {'n_estimators': 1844, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:50:36,654] Trial 72 finished with value: 0.5935080705280994 and parameters: {'n_estimators': 1827, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:50:50,497] Trial 73 finished with value: 0.5959129932859054 and parameters: {'n_estimators': 1540, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:51:02,534] Trial 74 finished with value: 0.596672170314298 and parameters: {'n_estimators': 1701, 'max_depth': 37, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:51:11,073] Trial 75 finished with value: 0.5956903979743098 and parameters: {'n_estimators': 1782, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:51:35,183] Trial 76 finished with value: 0.5944084504209314 and parameters: {'n_estimators': 1883, 'max_depth': 47, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.3}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:51:47,329] Trial 77 finished with value: 0.5952918862302453 and parameters: {'n_estimators': 1944, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:52:01,332] Trial 78 finished with value: 0.5977327694195264 and parameters: {'n_estimators': 1740, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:52:15,186] Trial 79 finished with value: 0.5976680912287936 and parameters: {'n_estimators': 1728, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:52:26,963] Trial 80 finished with value: 0.597885154468429 and parameters: {'n_estimators': 1748, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:52:38,770] Trial 81 finished with value: 0.5979375965991487 and parameters: {'n_estimators': 1739, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:52:50,495] Trial 82 finished with value: 0.5962287944425523 and parameters: {'n_estimators': 1745, 'max_depth': 28, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:01,784] Trial 83 finished with value: 0.5952938352729045 and parameters: {'n_estimators': 1681, 'max_depth': 26, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:12,448] Trial 84 finished with value: 0.5964083000256958 and parameters: {'n_estimators': 1596, 'max_depth': 30, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:25,222] Trial 85 finished with value: 0.5960119187992695 and parameters: {'n_estimators': 1886, 'max_depth': 29, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:37,184] Trial 86 finished with value: 0.5976324312753565 and parameters: {'n_estimators': 1774, 'max_depth': 32, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:47,859] Trial 87 finished with value: 0.5964002761413852 and parameters: {'n_estimators': 1548, 'max_depth': 32, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:53:58,881] Trial 88 finished with value: 0.5978345899083947 and parameters: {'n_estimators': 1627, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:54:09,767] Trial 89 finished with value: 0.5964820321956631 and parameters: {'n_estimators': 1621, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:54:19,354] Trial 90 finished with value: 0.5963004377772089 and parameters: {'n_estimators': 1443, 'max_depth': 30, 'min_samples_split': 19, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:54:31,086] Trial 91 finished with value: 0.5977580700694984 and parameters: {'n_estimators': 1713, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:54:42,465] Trial 92 finished with value: 0.5977919338872396 and parameters: {'n_estimators': 1705, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:54:54,034] Trial 93 finished with value: 0.5954549353779893 and parameters: {'n_estimators': 1715, 'max_depth': 24, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:55:05,086] Trial 94 finished with value: 0.5977136287330237 and parameters: {'n_estimators': 1660, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:55:23,948] Trial 95 finished with value: 0.5922268073925295 and parameters: {'n_estimators': 1077, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 0.5}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:55:32,548] Trial 96 finished with value: 0.5903991161971149 and parameters: {'n_estimators': 1669, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:55:39,265] Trial 97 finished with value: 0.5850116192781479 and parameters: {'n_estimators': 1750, 'max_depth': 26, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:55:58,333] Trial 98 finished with value: 0.5938191630272261 and parameters: {'n_estimators': 1561, 'max_depth': 27, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.3}. Best is trial 39 with value: 0.5980671632923581.
# [I 2025-07-06 13:56:08,519] Trial 99 finished with value: 0.5954523339082011 and parameters: {'n_estimators': 1496, 'max_depth': 25, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 0.1}. Best is trial 39 with value: 0.5980671632923581.
# 최적화 완료!
# 최고 점수: 0.5981
# 최적 하이퍼파라미터:
#   n_estimators: 1892
#   max_depth: 31
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.1

# %%
# 최적 하이퍼파라미터로 모델 훈련
print("\n검증 세트로 성능 확인...")
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train_scaled, y_train, test_size=0.2, random_state=42
)

best_model = RandomForestRegressor(**study.best_params, random_state=42, n_jobs=-1)
best_model.fit(X_train_split, y_train_split)

y_val_pred = best_model.predict(X_val)
val_score = competition_score(y_val, y_val_pred)
val_nrmse = normalized_rmse(y_val, y_val_pred)
val_pearson = pearson_correlation(y_val, y_val_pred)

print(f"검증 세트 성능:")
print(f"  Competition Score: {val_score:.4f}")
print(f"  NRMSE: {val_nrmse:.4f}")
print(f"  Pearson: {val_pearson:.4f}")
# Out:
# 검증 세트로 성능 확인...
# 검증 세트 성능:
#   Competition Score: 0.6205
#   NRMSE: 0.2345
#   Pearson: 0.4754

# %%
# 특성 중요도 분석
feature_importance = best_model.feature_importances_
top_features_idx = np.argsort(feature_importance)[-15:]

print(f"\n상위 15개 중요 특성:")
feature_names = (['MolWt', 'MolLogP', 'NumHAcceptors', 'NumHDonors', 'TPSA', 
                 'NumRotatableBonds', 'NumAromaticRings', 'NumHeteroatoms', 
                 'FractionCSP3', 'NumAliphaticRings', 'NumAromaticHeterocycles',
                 'NumSaturatedHeterocycles', 'NumAliphaticHeterocycles', 
                 'HeavyAtomCount', 'RingCount', 'NOCount', 'NHOHCount', 
                 'NumRadicalElectrons'] + 
                [f'Morgan_{i}' for i in range(2048)] + 
                [f'MACCS_{i}' for i in range(166)])

for idx in reversed(top_features_idx):
    print(f"  {feature_names[idx]}: {feature_importance[idx]:.4f}")
# Out:
# 상위 15개 중요 특성:
#   MolLogP: 0.0663
#   MolWt: 0.0324
#   HeavyAtomCount: 0.0258
#   FractionCSP3: 0.0174
#   TPSA: 0.0161
#   NumAromaticRings: 0.0126
#   NumRotatableBonds: 0.0102
#   RingCount: 0.0097
#   Morgan_1603: 0.0071
#   MACCS_125: 0.0070
#   NumHeteroatoms: 0.0064
#   NumHAcceptors: 0.0060
#   NOCount: 0.0057
#   MACCS_136: 0.0057
#   MACCS_98: 0.0046

# %%
# 전체 데이터로 최종 훈련
print("\n전체 데이터로 최종 모델 훈련...")
final_model = RandomForestRegressor(**study.best_params, random_state=42, n_jobs=-1)
final_model.fit(X_train_scaled, y_train)
# Out:
# 전체 데이터로 최종 모델 훈련...
# RandomForestRegressor(max_depth=31, max_features=0.1, min_samples_split=5,
#                       n_estimators=1892, n_jobs=-1, random_state=42)

# %%
# 테스트 데이터 예측
print("테스트 데이터 예측 중...")
test_preds = final_model.predict(X_test_scaled)

# 결과 저장
submission['Inhibition'] = test_preds
submission.to_csv('random_forest_optuna_submission.csv', index=False)

print(f"\n=== 최종 결과 ===")
print(f"시도 횟수: {n_trials}")
print(f"최고 CV 점수: {study.best_value:.4f}")
print(f"검증 점수: {val_score:.4f}")
print("예측 결과 저장: random_forest_optuna_submission.csv")
# Out:
# 테스트 데이터 예측 중...
#
# === 최종 결과 ===
# 시도 횟수: 100
# 최고 CV 점수: 0.5981
# 검증 점수: 0.6205
# 예측 결과 저장: random_forest_optuna_submission.csv
